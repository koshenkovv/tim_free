# %% [markdown]
# Задание №1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('list1.csv',encoding='cp1251',delimiter=';')

# %%
df['Картофель'] = df['Картофель'].str.replace(',','.')

# %%
df['Год'] = df['Год'].astype(int)
df['Картофель'] = df['Картофель'].astype(float)
df
# Out:
#      Год  Картофель
# 0   1991     4102.0
# 1   1992     2730.4
# 2   1993     2130.8
# 3   1994     1350.5
# 4   1995     1161.8
# 5   1996     1156.5
# 6   1997     1058.9
# 7   1998     1123.6
# 8   1999      891.4
# 9   2000      855.7
# 10  2001      951.0
# 11  2002      942.9
# 12  2003      846.1
# 13  2004     1050.4
# 14  2005     1275.0
# 15  2006     1469.0
# 16  2007     1742.0
# 17  2008     1948.0
# 18  2009     2098.0
# 19  2010     1890.0
# 20  2011     1827.0
# 21  2012     2367.0
# 22  2013     2335.0
# 23  2014     2255.0
# 24  2015     2575.0
# 25  2016     2851.0
# 26  2017     2782.0
# 27  2018     2726.0
# 28  2019     2772.0

# %%
df.plot(x="Год", y=["Картофель"],title='Реализация продуктов растениеводства сельскохозяйственными организациями',linestyle="-.",color='purple',grid='True')
# Out:
# <AxesSubplot:title={'center':'Реализация продуктов растениеводства сельскохозяйственными организациями'}, xlabel='Год'>

# %% [markdown]
# Задание №2

# %%
df2 = pd.read_csv('list2.csv',encoding='cp1251',delimiter=';')

# %%
x2 = df2['Интервалы по возрасту']
y2 = df2['Румыния']

plt.figure(figsize=(15, 5))
plt.title('Распределение населения по возрастным группам по странам мира')
plt.xlabel('Интервалы по возрасту')
plt.bar(x2,y2,color='blue')
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# Задание №3

# %%
df3 = pd.read_csv('list3.csv',encoding='cp1251',delimiter=';')
df3
# Out:
#     Номер предприятия Выручка в расчете на 100 га с.-х. угодий, тыс. руб.  \
# 0                   1                                               1193
# 1                   2                                             1255,6
# 2                   3                                             3088,3
# 3                   4                                             2626,6
# 4                   5                                             4557,3
# 5                   6                                             7614,8
# 6                   7                                             3958,3
# 7                   8                                               2866
# 8                   9                                             5917,9
# 9                  10                                             4855,4
# 10                 11                                             4433,1
# 11                 12                                             4466,3
# 12                 13                                             8327,1
# 13                 14                                             4916,9
# 14                 15                                             3735,8
#
#     Численность работников  в расчете на 100 га с.-х. угодий, чел.
# 0                                                   1
# 1                                                   1
# 2                                                   2
# 3                                                   1
# 4                                                   4
# 5                                                   6
# 6                                                   1
# 7                                                   3
# 8                                                   3
# 9                                                   2
# 10                                                  3
# 11                                                  4
# 12                                                  7
# 13                                                  4
# 14                                                  2

# %%
x3 = df3['Численность работников  в расчете на 100 га с.-х. угодий, чел.']
y3 = df3['Выручка в расчете на 100 га с.-х. угодий, тыс. руб.']

# %%
plt.figure(figsize=(10, 5))
plt.title('Характеристика сельскохозяйственных предприятий Краснодарского края, 2013 г.')
plt.xlabel('Численность работников  в расчете на 100 га с.-х. угодий, чел.')
plt.ylabel('Выручка в расчете на 100 га с.-х. угодий, тыс. руб.')
plt.scatter(x3,y3,color='red',marker='*')

# %% [markdown]
# Задание 4

# %%
df4=pd.read_csv("list4.csv",encoding='cp1251',delimiter=';')
df4_sort=df4.sort_values(by=['Среднедушевые денежные доходы населения'])
df4_sort
# Out:
#                  Субъект РФ  Среднедушевые денежные доходы населения
# 11      Республика Калмыкия                                     8829
# 8         Псковская область                                    14185
# 10        Республика Адыгея                                    14272
# 14    Волгоградская область                                    14519
# 3       Вологодская область                                    15638
# 5     Ленинградская область                                    15932
# 15       Ростовская область                                    16010
# 13     Астраханская область                                    16032
# 4   Калининградская область                                    16880
# 7      Новгородская область                                    16981
# 0        Республика Карелия                                    17543
# 12       Краснодарский край                                    18796
# 2     Архангельская область                                    21455
# 1           Республика Коми                                    23925
# 6        Мурманская область                                    25303
# 9        г. Санкт-Петербург                                    26069

# %%
y4 = df4_sort['Среднедушевые денежные доходы населения']
x4 = df4_sort['Субъект РФ']

plt.title('Распределение населения по возрастным группам по странам мира')
plt.xlabel('Интервалы по возрасту')
plt.bar(x4,y4)
# Out:
# <BarContainer object of 16 artists>

# %%
df5=pd.read_csv('list5.csv',encoding='cp1251',delimiter=';')
df5
# Out:
#                                           Организации Количество
# 0    для решения организационных, управленческих и...       52,9
# 1                            антивирусные программы3)       76,3
# 2   для осуществления финансовых расчетов в электр...       55,3
# 3              электронные справочно-правовые системы       51,8
# 4                для управления продажами и закупками       41,8
# 5   для предоставления доступа к базам данных чере...       31,0
# 6                                 обучающие программы       14,2
# 7   для управления автоматизированным производство...       14,9
# 8                                  для проектирования       10,8
# 9                    редакционно-издательские системы        5,1
# 10                          CRM, ERP, SCM – системы3)       15,9
# 11                           для научных исследований        3,4
# 12                                              Всего      373,4

# %%
df5['Количество'] = df5['Количество'].str.replace(',','.')
df5['Количество'] = df5['Количество'].astype(float)

# %%
x5=df5['Количество']
y5=df5['Организации']
plt.figure(figsize=(15, 20))
plt.pie(x5,labels=y5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
