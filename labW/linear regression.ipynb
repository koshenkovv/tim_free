# %%
import pandas as pd

# %%
df = pd.read_excel('Исходные данные_Краснодар.xlsx')
df
# Out:
#     Номер хозяйства  Урожайность зерновых и зернобобовых, ц/га  \
# 0                11                                  38.603488
# 1                23                                  36.111111
# 2                27                                  18.176000
# 3                40                                  40.021690
# 4                44                                  39.579568
# 5                47                                  31.000000
# 6                52                                  37.298762
# 7                54                                  33.653041
# 8               108                                  42.155054
# 9               126                                  24.343947
# 10              138                                  37.505882
# 11              141                                  32.763293
# 12              142                                  34.186957
# 13              159                                  45.000000
# ...

# %%
print(df.corr())
# Out:
#                                                     Номер хозяйства  \
# Номер хозяйства                                            1.000000
# Урожайность зерновых и зернобобовых, ц/га                  0.409184
# Среднегодовая стоимость основных средств произв...         0.980662
# Затраты на минеральные удобрения в расчете на 1...         0.296047
# Коэффициент распаханности                                  0.065782
#
#                                                     Урожайность зерновых и зернобобовых, ц/га  \
# Номер хозяйства                                                                      0.409184
# Урожайность зерновых и зернобобовых, ц/га                                            1.000000
# Среднегодовая стоимость основных средств произв...                                   0.415138
# Затраты на минеральные удобрения в расчете на 1...                                   0.429456
# ...

# %%
df.columns
# Out:
# Index(['Номер хозяйства', 'Урожайность зерновых и зернобобовых, ц/га',
#        'Среднегодовая стоимость основных средств производства в расчете на 100 га с.-х. угодий, тыс. руб.',
#        'Затраты на минеральные удобрения в расчете на 1 га посевной площади зерновых и зернобобовых, тыс. руб.',
#        'Коэффициент распаханности'],
#       dtype='object')

# %%
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     9.162
# Date:                Mon, 17 Oct 2022   Prob (F-statistic):            0.00412
# Time:                        13:26:33   Log-Likelihood:                -164.98
# No. Observations:                  46   AIC:                             334.0
# Df Residuals:                      44   BIC:                             337.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     32.5404      2.843     11.446      0.000      26.811      38.270
# ...
